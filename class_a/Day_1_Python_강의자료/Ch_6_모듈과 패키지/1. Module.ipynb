# %% [markdown]
# # 1. Module

# %% [markdown]
# ### 1) Module import

# %% [markdown]
# #### import 모듈

# %%
import math

n = math.factorial(5)
n
# Out:
# 120

# %% [markdown]
# #### from 모듈 import 함수

# %%
from math import factorial

n = factorial(5)
n
# Out:
# 120

# %%
from math import factorial, pi

n = factorial(1) + pi
n
# Out:
# 4.141592653589793

# %%
from math import *

n = cos(pi)
n
# Out:
# -1.0
